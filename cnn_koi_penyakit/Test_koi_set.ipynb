# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model('trained_model.keras')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 128, 128, 32)      896
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 32)      9248
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 64)        18496
#
#  conv2d_11 (Conv2D)          (None, 62, 62, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 31, 31, 128)       73856
#
#  conv2d_13 (Conv2D)          (None, 29, 29, 128)       147584
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 256)       295168
#
#  conv2d_15 (Conv2D)          (None, 12, 12, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
# ...

# %% [markdown]
# ### Visualizing Single Image of Test set

# %%
import cv2
image_path = "test/parasiteich.png"
#Reading image
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Convert bgr to rgb

#Displaying image
plt.imshow(img)
plt.title("Test Image")
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ### Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path, target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr]) #convert single image to batch because we were trained model with batch size
print(input_arr.shape)
# Out:
# (1, 128, 128, 3)

# %%
prediction = model.predict(input_arr)
prediction,prediction.shape
# Out:
# 1/1 [==============================] - 9s 9s/step
# (array([[1.8148447e-05, 1.4175102e-07, 9.9998176e-01]], dtype=float32), (1, 3))

# %%
result_index = np.argmax(prediction)
result_index
# Out:
# 2

# %%
class_name = ['Bacterial Diseases',
 'Fungal Diseases',
 #'White Tail Diseases',
 'Parasitic Diseases']
 #'White Tail Diseases']

# %%
#Displaying result of disease prediction
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %% [markdown]
# ### Laporan deteksi

# %%
# 2 kali gambar parasite terdeteksi fungal dan bacterial
# fungal terdeteksi bacterial
# fungal terdeteksi parasite
# bacterial as white tail

#fungal fungal.png, 2,
#fungus 5
#bacterial 5,bacterialzoom,bacterialzoo
#parasite parasite-fungus, parasitemucuss, parasitemucus
#finrot 6,5,3,2, finrot.png, fin-rot.png

class_name = ['Bacterial Diseases',
 'Fungal Diseases',
 #'White Tail Diseases',
 'Parasitic Diseases']
 #'White Tail Diseases']

# %%
import numpy as np

# Your class names
class_name = ['Bacterial Diseases', 'Fungal Diseases', 'Parasitic Diseases']

# Prediction example (batch of 2 samples)
prediction = np.array([[0.8, 0.1, 0.1],  # Sample 1
                       [0.2, 0.5, 0.3]]) # Sample 2

# Get predicted class indices
predicted_indices = np.argmax(prediction, axis=1)

# Map indices to class names
predicted_classes = [class_name[idx] for idx in predicted_indices]

# Display results
for i, cls in enumerate(predicted_classes):
    print(f"Sample {i+1}: Predicted Class - {cls}")
